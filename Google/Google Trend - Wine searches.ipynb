# %% [markdown]
# # Timeseries of trending wines based on Google searches

# %%
#Import the necessary packages
import pandas as pd                        
from pytrends.request import TrendReq
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading the data from a .csv file rather than running through every cell of this notebook
df_trend_region = pd.read_csv("combined_regions_google_trend.csv")

# %% [markdown]
# ## Google Trend - Wine searches - Region : Jura

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Jura
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Jura", "white wine + Jura", "rose wine + Jura", "sparkling wine + Jura"],timeframe='2021-10-01 2022-10-01', geo="GB")
Jura = pytrend.interest_over_time()

# %% [markdown]
# ## Google Trend - Wine searches - Region : Alsace

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Alsace
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Alsace", "white wine + Alsace", "rose wine + Alsace", "sparkling wine + Alsace" 
                                 ],timeframe='2021-10-01 2022-10-01', geo="GB")
Alsace = pytrend.interest_over_time()

# %% [markdown]
# ## Google Trend - Wine searches - Region : Catalonia

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Catalonia
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Catalonia", "white wine + Catalonia", "rose wine + Catalonia", 
                                 "sparkling wine + Catalonia"],timeframe='2021-10-01 2022-10-01', geo="GB")
Catalonia= pytrend.interest_over_time()

# %% [markdown]
# ## Google Trend - Wine searches - Region : Sicily

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Sicily
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Sicily", "white wine + Sicily", "rose wine + Sicily", 
                                 "sparkling wine + Sicily"],timeframe='2021-10-01 2022-10-01', geo="GB")
Sicily = pytrend.interest_over_time()
Sicily
# Out:
#             red wine + Sicily  white wine + Sicily  rose wine + Sicily  \
# date
# 2021-10-03                 52                   32                  20
# 2021-10-10                 50                   30                  17
# 2021-10-17                 50                   31                  18
# 2021-10-24                 57                   32                  20
# 2021-10-31                 52                   29                  15
# 2021-11-07                 60                   31                  14
# 2021-11-14                 54                   28                  14
# 2021-11-21                 59                   30                  15
# 2021-11-28                 58                   29                  14
# 2021-12-05                 62                   31                  15
# 2021-12-12                 68                   34                  17
# 2021-12-19                100                   44                  21
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Tuscany

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Tuscany
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Tuscany", "white wine + Tuscany", "rose wine + Tuscany", 
                                 "sparkling wine + Tuscany"],timeframe='2021-10-01 2022-10-01', geo="GB")
Tuscany = pytrend.interest_over_time()
Tuscany
# Out:
#             red wine + Tuscany  white wine + Tuscany  rose wine + Tuscany  \
# date
# 2021-10-03                  45                    26                   12
# 2021-10-10                  46                    26                   12
# 2021-10-17                  46                    26                   12
# 2021-10-24                  48                    26                   12
# 2021-10-31                  50                    26                   11
# 2021-11-07                  58                    28                   10
# 2021-11-14                  51                    24                   10
# 2021-11-21                  56                    26                   11
# 2021-11-28                  57                    27                   11
# 2021-12-05                  63                    31                   14
# 2021-12-12                  67                    32                   14
# 2021-12-19                 100                    41                   17
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Loire

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Loire
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Sicily", "white wine + Loire", "rose wine + Loire", "sparkling + Loire"], timeframe='2021-10-01 2022-10-01', geo="GB")
Loire = pytrend.interest_over_time()
Loire
# Out:
#             red wine + Sicily  white wine + Loire  rose wine + Loire  \
# date
# 2021-10-03                 52                  23                  9
# 2021-10-10                 50                  22                  8
# 2021-10-17                 50                  23                  9
# 2021-10-24                 57                  23                  9
# 2021-10-31                 52                  24                  9
# 2021-11-07                 60                  25                  8
# 2021-11-14                 54                  23                  8
# 2021-11-21                 59                  25                 10
# 2021-11-28                 58                  25                 11
# 2021-12-05                 62                  30                 12
# 2021-12-12                 68                  31                 13
# 2021-12-19                100                  39                 17
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Piemonte

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Piemonte
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Piemonte", "white wine + Piemonte", "rose wine + Piemonte", "sparkling + Piemonte"],timeframe='2021-10-01 2022-10-01', geo="GB")
Piemonte = pytrend.interest_over_time()
Piemonte
# Out:
#             red wine + Piemonte  white wine + Piemonte  rose wine + Piemonte  \
# date
# 2021-10-03                   44                     23                     8
# 2021-10-10                   45                     22                     8
# 2021-10-17                   44                     23                     8
# 2021-10-24                   47                     23                     8
# 2021-10-31                   47                     23                     7
# 2021-11-07                   57                     25                     6
# 2021-11-14                   49                     23                     6
# 2021-11-21                   53                     25                     9
# 2021-11-28                   56                     26                     9
# 2021-12-05                   61                     29                    10
# 2021-12-12                   67                     30                    12
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Bordeaux

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Bordeaux
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Bordeaux", "white wine + Bordeaux", "rose wine + Bordeaux", "sparkling + Bordeaux"],timeframe='2021-10-01 2022-10-01', geo="GB")
Bordeaux= pytrend.interest_over_time()
Bordeaux
# Out:
#             red wine + Bordeaux  white wine + Bordeaux  rose wine + Bordeaux  \
# date
# 2021-10-03                   50                     31                    19
# 2021-10-10                   50                     30                    18
# 2021-10-17                   53                     32                    20
# 2021-10-24                   54                     30                    18
# 2021-10-31                   64                     41                    26
# 2021-11-07                   64                     37                    20
# 2021-11-14                   57                     31                    18
# 2021-11-21                   60                     34                    19
# 2021-11-28                   61                     33                    19
# 2021-12-05                   70                     40                    23
# 2021-12-12                   69                     39                    21
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Veneto

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Veneto
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Veneto", "white wine + Veneto", "rose wine + Veneto",
                                 "sparkling wine + Veneto"],timeframe='2021-10-01 2022-10-01', geo="GB")
Veneto = pytrend.interest_over_time()
Veneto
# Out:
#             red wine + Veneto  white wine + Veneto  rose wine + Veneto  \
# date
# 2021-10-03                 43                   23                   8
# 2021-10-10                 45                   22                   8
# 2021-10-17                 44                   23                   8
# 2021-10-24                 47                   23                   7
# 2021-10-31                 49                   23                   7
# 2021-11-07                 57                   25                   7
# 2021-11-14                 50                   23                   7
# 2021-11-21                 55                   25                   8
# 2021-11-28                 57                   26                   9
# 2021-12-05                 62                   29                  10
# 2021-12-12                 67                   31                  12
# 2021-12-19                100                   39                  16
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Trentino-Alto Adige

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Trentino-Alto Adige
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Trentino-Alto Adige", "white wine + Trentino-Alto Adige", "rose wine + Trentino-Alto Adige",
                                 "sparkling wine + Trentino-Alto Adige"],timeframe='2021-10-01 2022-10-01', geo="GB")
Trentino= pytrend.interest_over_time()
Trentino
# Out:
#             red wine + Trentino-Alto Adige  white wine + Trentino-Alto Adige  \
# date
# 2021-10-03                              43                                23
# 2021-10-10                              44                                21
# 2021-10-17                              44                                22
# 2021-10-24                              47                                22
# 2021-10-31                              48                                22
# 2021-11-07                              56                                25
# 2021-11-14                              49                                21
# 2021-11-21                              54                                24
# 2021-11-28                              55                                25
# 2021-12-05                              61                                28
# 2021-12-12                              67                                30
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Rhône

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Rhône
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Rhône", "white wine + Rhône", "rose wine + Rhône",
                                 "sparkling wine + Rhône"],timeframe='2021-10-01 2022-10-01', geo="GB")
Rhone = pytrend.interest_over_time()
Rhone
# Out:
#             red wine + Rhône  white wine + Rhône  rose wine + Rhône  \
# date
# 2021-10-03                43                  22                  8
# 2021-10-10                44                  21                  7
# 2021-10-17                44                  22                  7
# 2021-10-24                47                  22                  7
# 2021-10-31                48                  23                  6
# 2021-11-07                57                  25                  5
# 2021-11-14                49                  22                  6
# 2021-11-21                54                  25                  8
# 2021-11-28                55                  25                  8
# 2021-12-05                61                  28                  9
# 2021-12-12                67                  31                 11
# 2021-12-19               100                  39                 14
# 2021-12-26                64                  27                  8
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Roussillon

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Roussillon
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Roussillon", "white wine + Roussillon", "rose wine + Roussillon",
                                 "sparkling wine + Roussillon"],timeframe='2021-10-01 2022-10-01', geo="GB")
Roussillon = pytrend.interest_over_time()
Roussillon
# Out:
#             red wine + Roussillon  white wine + Roussillon  \
# date
# 2021-10-03                     43                       23
# 2021-10-10                     44                       21
# 2021-10-17                     44                       22
# 2021-10-24                     47                       22
# 2021-10-31                     47                       23
# 2021-11-07                     57                       25
# 2021-11-14                     49                       22
# 2021-11-21                     54                       25
# 2021-11-28                     55                       25
# 2021-12-05                     61                       28
# 2021-12-12                     67                       30
# 2021-12-19                    100                       39
# 2021-12-26                     63                       27
# 2022-01-02                     53                       29
# 2022-01-09                     50                       25
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Rioja

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Rioja
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Rioja", "white wine + Rioja", "rose wine + Rioja",
                                 "sparkling wine + Rioja"],timeframe='2021-10-01 2022-10-01', geo="GB")
Rioja = pytrend.interest_over_time()
Rioja
# Out:
#             red wine + Rioja  white wine + Rioja  rose wine + Rioja  \
# date
# 2021-10-03                43                  24                 12
# 2021-10-10                44                  24                 12
# 2021-10-17                44                  25                 12
# 2021-10-24                46                  25                 11
# 2021-10-31                47                  24                 11
# 2021-11-07                55                  26                 10
# 2021-11-14                48                  25                 11
# 2021-11-21                55                  28                 14
# 2021-11-28                57                  28                 14
# 2021-12-05                61                  31                 16
# 2021-12-12                67                  35                 19
# 2021-12-19               100                  48                 26
# 2021-12-26                64                  31                 16
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Champagne

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Champagne
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Champagne", "white wine + Champagne", "rose wine + Champagne",
                                 "sparkling wine + Champagne"],timeframe='2021-10-01 2022-10-01', geo="GB")
Champagne = pytrend.interest_over_time()
Champagne
# Out:
#             red wine + Champagne  white wine + Champagne  \
# date
# 2021-10-03                    43                      34
# 2021-10-10                    43                      34
# 2021-10-17                    43                      34
# 2021-10-24                    45                      34
# 2021-10-31                    45                      36
# 2021-11-07                    54                      41
# 2021-11-14                    51                      40
# 2021-11-21                    54                      43
# 2021-11-28                    55                      43
# 2021-12-05                    65                      51
# 2021-12-12                    72                      60
# 2021-12-19                   100                      76
# 2021-12-26                    80                      68
# 2022-01-02                    53                      44
# 2022-01-09                    48                      37
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Burgund

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Burgund
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Burgund","white wine + Burgund", "rose wine + Burgund", 
                                 "sparkling wine + Burgund"],timeframe='2021-10-01 2022-10-01', geo="GB")
Burgund = pytrend.interest_over_time()
Burgund
# Out:
#             red wine + Burgund  white wine + Burgund  rose wine + Burgund  \
# date
# 2021-10-03                  43                    22                    7
# 2021-10-10                  44                    22                    7
# 2021-10-17                  43                    22                    7
# 2021-10-24                  47                    22                    6
# 2021-10-31                  47                    22                    7
# 2021-11-07                  56                    25                    5
# 2021-11-14                  49                    22                    6
# 2021-11-21                  54                    24                    8
# 2021-11-28                  55                    25                    8
# 2021-12-05                  61                    27                    8
# 2021-12-12                  66                    29                   11
# 2021-12-19                 100                    39                   14
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Provence

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Provence
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Provence", "white wine + Provence", "rose wine + Provence", 
                                 "sparkling wine + Provence"],timeframe='2021-10-01 2022-10-01', geo="GB")
Provence = pytrend.interest_over_time()
Provence
# Out:
#             red wine + Provence  white wine + Provence  rose wine + Provence  \
# date
# 2021-10-03                   47                     27                    14
# 2021-10-10                   51                     30                    17
# 2021-10-17                   49                     30                    16
# 2021-10-24                   50                     28                    13
# 2021-10-31                   50                     27                    12
# 2021-11-07                   59                     30                    13
# 2021-11-14                   51                     26                    11
# 2021-11-21                   58                     28                    14
# 2021-11-28                   58                     29                    14
# 2021-12-05                   62                     30                    13
# 2021-12-12                   67                     31                    14
# ...

# %% [markdown]
# ## Google Trend - Wine searches - Region : Castilla y Léon

# %%
#Obtaining the trend-results of searching for red wine, white wine, rose wine or sparkling wine in the region Castilla y Léon
pytrend = TrendReq()
pytrend.build_payload(kw_list = ["red wine + Castilla y Léon", "white wine + Castilla y Léon", "rose wine + Castilla y Léon", 
                                 "sparkling wine + Castilla y Léon"],timeframe='2021-10-01 2022-10-01', geo="GB")
Castilla_y_Leon = pytrend.interest_over_time()
Castilla_y_Leon
# Out:
#             red wine + Castilla y Léon  white wine + Castilla y Léon  \
# date
# 2021-10-03                          43                            23
# 2021-10-10                          44                            21
# 2021-10-17                          44                            22
# 2021-10-24                          47                            22
# 2021-10-31                          48                            22
# 2021-11-07                          57                            25
# 2021-11-14                          49                            22
# 2021-11-21                          54                            24
# 2021-11-28                          55                            25
# 2021-12-05                          61                            28
# 2021-12-12                          67                            30
# 2021-12-19                         100                            39
# ...

# %% [markdown]
# ## Formatting algorithm

# %% [markdown]
# This function is designed to be ran after obtaining the google trends from all of the regions above. The function under is assuming you have ran through all of the regions, and as some of the regions doesn't contain any searches on our input (leaving no column on this), there needs to be some formatting of these columns. <br> <br>
# Don't run this if you just have read the .csv file in the second cell of the notebook

# %%
#Function that formats all necessary parameters in the data set that is sent as a variable to the function
def create_winetable(df, name):
    
    if len(df.columns)!=5:
        red = False
        white = False
        rose = False
        sparkling = False
        pos = 0
        
        #Checking which column(s) is(are) missing
        if df.columns[pos].startswith("red") == False:
            red = True
            df.loc[:, "red wine"] = 0
        pos+=1
        if df.columns[pos].startswith("white") == False:
            white = True
            df.loc[:, "white wine"] = 0
        pos+=1
        if df.columns[pos].startswith("rose") == False:
            rose = True
            df.loc[:, "rose wine"] = 0
        pos+=1
        if df.columns[pos].startswith("sparkling") == False:
            sparkling = True
            df.loc[:, "sparkling wine"] = 0
            
    df = df.reset_index()
    df.loc[:, "region"] = name
    df.columns = ["date", "red wine", "white wine", "sparkling wine", "rose wine", "isPartial", "region"]
    df.loc[:, "total_wines"] = df.loc[:, "red wine"] + df.loc[:,"white wine"] + df.loc[:,"rose wine"] + df.loc[:,"sparkling wine"]
    df.to_csv("%s.csv" %name)
    return df

# %%
#Creating two lists of every trending data set to make sure that everyone have the same structure and variables to later concatenate them
dataset_list = [Jura, Bordeaux, Castilla_y_Leon, Alsace, Catalonia, Sicily, Tuscany, Loire, Piemonte, Bordeaux, Veneto, Trentino, Rhone, Roussillon, Rioja, Champagne, Burgund, Provence]
name_list = ['Jura', 'Bordeaux', 'Castilla_y_Léon', 'Alsace', 'Catalonia', 'Sicily', 'Tuscany', 'Loire', 'Piemonte', 'Bordeaux', 'Veneto', 'Trentino', 'Rhône', 'Roussillon', 'Rioja', 'Champagne', 'Burgund', 'Provence']

#Temporary list to store the dataframes returned of the above function
dataframe_list = []

#Iterates through every dataframe of the trends, formatting the tables, returning a formatted data frame
for i in range(len(dataset_list)):
    df = create_winetable(dataset_list[i], name_list[i])
    dataframe_list.append(df)

#Creating a combined dataset of the above dataframe list
df_trend_region = pd.concat(dataframe_list)

#Storing it in a .csv file
df_trend_region.to_csv("combined_regions_google_trend.csv")

# %% [markdown]
# ## Visualization of trending total searches - Top 10 regions

# %%
#Getting top 10
top_regions = df_trend_region.groupby("region")["total_wines"].sum().sort_values(ascending = False)
top_top5_regions = top_regions.index[0:5]
top_next5_regions = top_regions.index[5:10]

#Creating data frame of the top 5 regions for plotting with a thicker line
df_region_top5 = df_trend_region[df_trend_region["region"].isin(top_top5_regions)]

#Creating data frame with the next 5 regions for ploitting with a thinner line than top 5
df_region_next5 = df_trend_region[df_trend_region["region"].isin(top_next5_regions)]

# %%
#Setting figure size
# for matplotlib
plt.style.use('seaborn-bright')
# for seaborn
# sns.set_style()
plt.rc('text', usetex=True)
plt.rc('font', family='Georgia', size=14)
plt.figure(figsize = (20,10))

#Plotting the figures
sns.lineplot(x = "date", y = "total_wines", hue = "region", data = df_region_top5, linewidth = 5)
sns.lineplot(x = "date", y = "total_wines", hue = "region", data = df_region_next5, linewidth = 0.5)

#Setting title
plt.title("Total searches for wine per region", fontsize = 25, fontfamily = "Georgia")

#Storing legend in a variable
leg = plt.legend()
tmp = 0

#Setting linewidth for the first 5
for line in range(5): leg.get_lines()[line].set_linewidth(5)

#Changing font of legend
plt.setp(leg.texts, family='Georgia', fontsize = 15)

#Setting xticks for the graph
# pos = [i for i in range(0, 52, 4)]
# mnth = ["10-2021", "11-2021", "12-2021", "01-2022", "02-2022", "03-2022", "04-2022", "05-2022", "06-2022", "07-2022", "08-2022", "09-2022", "10-2022"]
# plt.gca().set(xticks = pos, xticklabels=mnth)

#Setting xlabel and ylabel
plt.xlabel("Date", fontsize = 15, fontfamily = "Georgia")
plt.ylabel("Total searches - Top 10", fontsize = 15, fontfamily = "Georgia")

#Saving the figure
plt.savefig("trend.jpeg",dpi=600)

#Displaying the figure
plt.show()
